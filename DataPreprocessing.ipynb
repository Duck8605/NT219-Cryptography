# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path = '/content/drive/MyDrive/Elliptic++ Dataset'

df_tx_classes = pd.read_csv(path + '/txs_classes.csv')
df_tx_edgelist = pd.read_csv(path + '/txs_edgelist.csv')
df_tx_features = pd.read_csv(path + '/txs_features.csv')
df_tx_features.head()
# Out:
#     txId  Time step  Local_feature_1  Local_feature_2  Local_feature_3  \
# 0   3321          1        -0.169615        -0.184668        -1.201369
# 1  11108          1        -0.137586        -0.184668        -1.201369
# 2  51816          1        -0.170103        -0.184668        -1.201369
# 3  68869          1        -0.114267        -0.184668        -1.201369
# 4  89273          1         5.202107        -0.210553        -1.756361
#
#    Local_feature_4  Local_feature_5  Local_feature_6  Local_feature_7  \
# 0        -0.121970        -0.043875        -0.113002        -0.061584
# 1        -0.121970        -0.043875        -0.113002        -0.061584
# 2        -0.121970        -0.043875        -0.113002        -0.061584
# 3         0.028105        -0.043875        -0.113002         0.547008
# 4        -0.121970       260.090707        -0.113002        -0.061584
#
#    Local_feature_8  ...  in_BTC_min  in_BTC_max  in_BTC_mean  in_BTC_median  \
# ...

# %%
# File of Actor Dataset here
df_wallets_features = pd.read_csv(path + '/wallets_features.csv')
df_wallets_classes = pd.read_csv(path + '/wallets_classes.csv')
df_addraddr_edgelist = pd.read_csv(path + '/AddrAddr_edgelist.csv')
df_addrtx_edgelist = pd.read_csv(path + '/AddrTx_edgelist.csv')
df_txaddr_edgelist = pd.read_csv(path + '/TxAddr_edgelist.csv')
df_wallets_features_classes_combined = pd.read_csv(path + '/wallets_features_classes_combined.csv')

# %%
df_tx_edgelist.head()
# Out:
#        txId1      txId2
# 0  230425980    5530458
# 1  232022460  232438397
# 2  230460314  230459870
# 3  230333930  230595899
# 4  232013274  232029206

# %% [markdown]
# # Actor Dataset

# %%
df_ransomware = pd.read_csv('/content/drive/MyDrive/ransom.csv', header = None, names = ['address'])

# %%
df_ransomware.head()
# Out:
#                               address
# 0  15m7FP7U4kDJhAVtjjUdUB8WYswpf7Dtho
# 1  1Nm2TMEFEdyb2BP6tLyuREoKECztibuK6P
# 2  1LJYrTxrQA5pFRRg2bSyJLT6MGezmMBVfX
# 3  1EiCssanXmavzjtffYHzK6aVeQHngUxX1s
# 4  1H65AnxCg7mT4rTZmRzH8cxENk1N12rhkZ

# %%
print ("Actor dataset: Column name, non-null count, data type...\n")
df_wallets_features_classes_combined.info()
# Out:
# Actor dataset: Column name, non-null count, data type...
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268260 entries, 0 to 1268259
# Data columns (total 58 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   address                        1268260 non-null  object
#  1   Time step                      1268260 non-null  int64
#  2   class                          1268260 non-null  int64
#  3   num_txs_as_sender              1268260 non-null  float64
#  4   num_txs_as receiver            1268260 non-null  float64
#  5   first_block_appeared_in        1268260 non-null  float64
#  6   last_block_appeared_in         1268260 non-null  float64
#  7   lifetime_in_blocks             1268260 non-null  float64
#  8   total_txs                      1268260 non-null  float64
#  9   first_sent_block               1268260 non-null  float64
# ...

# %%
df_wallets_features_classes_combined.describe()
# Out:
#           Time step         class  num_txs_as_sender  num_txs_as receiver  \
# count  1.268260e+06  1.268260e+06       1.268260e+06         1.268260e+06
# mean   2.402671e+01  2.687704e+00       1.270038e+01         6.566587e+00
# std    1.504961e+01  5.097747e-01       8.867257e+01         4.582542e+01
# min    1.000000e+00  1.000000e+00       0.000000e+00         0.000000e+00
# 25%    1.000000e+01  2.000000e+00       0.000000e+00         1.000000e+00
# 50%    2.300000e+01  3.000000e+00       1.000000e+00         1.000000e+00
# 75%    3.800000e+01  3.000000e+00       1.000000e+00         1.000000e+00
# max    4.900000e+01  3.000000e+00       1.453000e+03         5.480000e+02
#
#        first_block_appeared_in  last_block_appeared_in  lifetime_in_blocks  \
# count             1.268260e+06            1.268260e+06        1.268260e+06
# mean              4.349925e+05            4.407487e+05        5.756226e+03
# std               3.094160e+04            3.056447e+04        1.690569e+04
# ...

# %% [markdown]
# # Count NaN

# %%
# Count NaN
missing_values = df_wallets_features_classes_combined.isnull().sum()
print (missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %%
df_txaddr_edgelist.isna().sum()
# Out:
# input_address     0
# output_address    0
# dtype: int64

# %%
df_addraddr_edgelist.isna().sum()
# Out:
# input_address     0
# output_address    0
# dtype: int64

# %%
# Count illicit percentage - proof of imbalance data
print ("Percentage of each class: ")
df_wallets_classes['class'].value_counts(normalize=True) * 100
# Out:
# Percentage of each class:
# class
# 3    67.755443
# 2    30.511020
# 1     1.733537
# Name: proportion, dtype: float64

# %% [markdown]
# # Combine column

# %%
ransomware_address_set = set(df_ransomware['address'].dropna().unique())
df_wallets_features_classes_combined['is_ransomware'] = df_wallets_features_classes_combined['address'].isin(ransomware_address_set).astype(int)
df_wallets_features_classes_combined.head()
# Out:
#                              address  Time step  class  num_txs_as_sender  \
# 0  111112TykSw72ztDN2WJger4cynzWYC5w         25      2                0.0
# 1  1111DAYXhoxZx2tsRnzimfozo783x1yC2         25      3                0.0
# 2  1111DAYXhoxZx2tsRnzimfozo783x1yC2         29      3                0.0
# 3  1111DAYXhoxZx2tsRnzimfozo783x1yC2         39      3                0.0
# 4  1111DAYXhoxZx2tsRnzimfozo783x1yC2         39      3                0.0
#
#    num_txs_as receiver  first_block_appeared_in  last_block_appeared_in  \
# 0                  1.0                 439586.0                439586.0
# 1                  8.0                 439589.0                485959.0
# 2                  8.0                 439589.0                485959.0
# 3                  8.0                 439589.0                485959.0
# 4                  8.0                 439589.0                485959.0
#
#    lifetime_in_blocks  total_txs  first_sent_block  ...  \
# ...

# %%
df_wallets_features_classes_combined['address'].head()
# Out:
# 0    111112TykSw72ztDN2WJger4cynzWYC5w
# 1    1111DAYXhoxZx2tsRnzimfozo783x1yC2
# 2    1111DAYXhoxZx2tsRnzimfozo783x1yC2
# 3    1111DAYXhoxZx2tsRnzimfozo783x1yC2
# 4    1111DAYXhoxZx2tsRnzimfozo783x1yC2
# Name: address, dtype: object

# %%
ransomware_address_set = set(df_ransomware['address'].unique())
